# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import time

# %%
# Load dataset
data = pd.read_csv('GOOG.csv')

# %%
print(len(data))
# Out:
# 1258

# %%
import pandas as pd

# Assuming 'data' is your DataFrame
print(data.columns)

# Alternatively, you can use head() to see the first few rows including the column names
print(data.head())
# Out:
# Index(['symbol', 'date', 'close', 'high', 'low', 'open', 'volume', 'adjClose',
#        'adjHigh', 'adjLow', 'adjOpen', 'adjVolume', 'divCash', 'splitFactor'],
#       dtype='object')
#   symbol                       date   close    high       low    open
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48  \
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0  \
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['close'], label='Google Stock Price')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Over Time')
plt.legend()
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data['close']).reshape(-1, 1))

# %%
# Split data into train and test sets
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
# Function to create dataset with time steps
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
# Define time steps and create train and test datasets
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# Reshape data for LSTM input [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Build LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, 1)),
    LSTM(50),
    Dense(1)
])
# Out:
# C:\Users\TALHA\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Measure training time
start_time = time.time()

# %%
# Train model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=1)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 9s 167ms/step - loss: 3.8632e-05 - val_loss: 9.7605e-04
# Epoch 2/50
# 54/54 [==============================] - 8s 153ms/step - loss: 3.7644e-05 - val_loss: 0.0013
# Epoch 3/50
# 54/54 [==============================] - 7s 121ms/step - loss: 3.8536e-05 - val_loss: 0.0010
# Epoch 4/50
# 54/54 [==============================] - 8s 146ms/step - loss: 3.6884e-05 - val_loss: 0.0015
# Epoch 5/50
# 54/54 [==============================] - 7s 121ms/step - loss: 3.8629e-05 - val_loss: 0.0011
# Epoch 6/50
# 54/54 [==============================] - 8s 146ms/step - loss: 3.8757e-05 - val_loss: 9.6839e-04
# Epoch 7/50
# 54/54 [==============================] - 7s 123ms/step - loss: 3.6568e-05 - val_loss: 0.0011
# Epoch 8/50
# 54/54 [==============================] - 8s 142ms/step - loss: 3.4224e-05 - val_loss: 8.5460e-04
# Epoch 9/50
# 54/54 [==============================] - 8s 152ms/step - loss: 3.2559e-05 - val_loss: 9.8007e-04
# Epoch 10/50
# 54/54 [==============================] - 6s 120ms/step - loss: 3.2598e-05 - val_loss: 7.0874e-04
# Epoch 11/50
# 54/54 [==============================] - 8s 144ms/step - loss: 3.2133e-05 - val_loss: 8.8955e-04
# Epoch 12/50
# 54/54 [==============================] - 7s 124ms/step - loss: 3.3165e-05 - val_loss: 7.8035e-04
# Epoch 13/50
# 54/54 [==============================] - 8s 143ms/step - loss: 3.2469e-05 - val_loss: 6.8640e-04
# Epoch 14/50
# 54/54 [==============================] - 8s 144ms/step - loss: 2.8941e-05 - val_loss: 8.7385e-04
# Epoch 15/50
# 54/54 [==============================] - 8s 147ms/step - loss: 3.0076e-05 - val_loss: 6.4487e-04
# Epoch 16/50
# 54/54 [==============================] - 8s 143ms/step - loss: 3.3321e-05 - val_loss: 6.8580e-04
# Epoch 17/50
# 54/54 [==============================] - 7s 122ms/step - loss: 2.9881e-05 - val_loss: 8.3070e-04
# Epoch 18/50
# 54/54 [==============================] - 8s 143ms/step - loss: 2.8672e-05 - val_loss: 5.9005e-04
# Epoch 19/50
# 54/54 [==============================] - 7s 127ms/step - loss: 2.7020e-05 - val_loss: 5.2413e-04
# Epoch 20/50
# 54/54 [==============================] - 8s 146ms/step - loss: 2.8007e-05 - val_loss: 6.0255e-04
# Epoch 21/50
# 54/54 [==============================] - 8s 144ms/step - loss: 2.7201e-05 - val_loss: 5.6358e-04
# Epoch 22/50
# 54/54 [==============================] - 7s 124ms/step - loss: 2.6219e-05 - val_loss: 6.0024e-04
# Epoch 23/50
# 54/54 [==============================] - 8s 146ms/step - loss: 2.5029e-05 - val_loss: 5.1376e-04
# Epoch 24/50
# 54/54 [==============================] - 6s 120ms/step - loss: 2.4431e-05 - val_loss: 4.5709e-04
# Epoch 25/50
# 54/54 [==============================] - 8s 145ms/step - loss: 2.4597e-05 - val_loss: 5.8382e-04
# Epoch 26/50
# 54/54 [==============================] - 7s 125ms/step - loss: 2.5496e-05 - val_loss: 5.2939e-04
# Epoch 27/50
# 54/54 [==============================] - 8s 146ms/step - loss: 2.4026e-05 - val_loss: 4.2414e-04
# Epoch 28/50
# 54/54 [==============================] - 8s 141ms/step - loss: 2.3894e-05 - val_loss: 3.7573e-04
# Epoch 29/50
# 54/54 [==============================] - 7s 124ms/step - loss: 2.5040e-05 - val_loss: 4.7864e-04
# Epoch 30/50
# 54/54 [==============================] - 8s 143ms/step - loss: 2.2529e-05 - val_loss: 5.0276e-04
# Epoch 31/50
# 54/54 [==============================] - 7s 126ms/step - loss: 2.2552e-05 - val_loss: 9.4083e-04
# Epoch 32/50
# 54/54 [==============================] - 8s 144ms/step - loss: 2.5220e-05 - val_loss: 3.0466e-04
# Epoch 33/50
# 54/54 [==============================] - 7s 122ms/step - loss: 2.2876e-05 - val_loss: 3.6329e-04
# Epoch 34/50
# 54/54 [==============================] - 8s 146ms/step - loss: 2.1302e-05 - val_loss: 3.9629e-04
# Epoch 35/50
# 54/54 [==============================] - 8s 140ms/step - loss: 2.1863e-05 - val_loss: 6.1233e-04
# Epoch 36/50
# 54/54 [==============================] - 7s 122ms/step - loss: 1.9350e-05 - val_loss: 3.0500e-04
# Epoch 37/50
# 54/54 [==============================] - 8s 148ms/step - loss: 2.1382e-05 - val_loss: 3.7056e-04
# Epoch 38/50
# 54/54 [==============================] - 7s 124ms/step - loss: 1.9984e-05 - val_loss: 4.7348e-04
# Epoch 39/50
# 54/54 [==============================] - 8s 147ms/step - loss: 1.9168e-05 - val_loss: 3.9063e-04
# Epoch 40/50
# 54/54 [==============================] - 7s 122ms/step - loss: 1.7798e-05 - val_loss: 3.9127e-04
# Epoch 41/50
# 54/54 [==============================] - 8s 145ms/step - loss: 1.6819e-05 - val_loss: 5.0094e-04
# Epoch 42/50
# 54/54 [==============================] - 8s 140ms/step - loss: 1.6534e-05 - val_loss: 3.6158e-04
# Epoch 43/50
# 54/54 [==============================] - 7s 128ms/step - loss: 2.0071e-05 - val_loss: 4.5282e-04
# Epoch 44/50
# 54/54 [==============================] - 10s 187ms/step - loss: 1.9666e-05 - val_loss: 3.9035e-04
# Epoch 45/50
# 54/54 [==============================] - 7s 122ms/step - loss: 1.7883e-05 - val_loss: 5.3365e-04
# Epoch 46/50
# 54/54 [==============================] - 8s 148ms/step - loss: 1.5691e-05 - val_loss: 3.4008e-04
# Epoch 47/50
# 54/54 [==============================] - 8s 144ms/step - loss: 1.4923e-05 - val_loss: 4.6569e-04
# Epoch 48/50
# 54/54 [==============================] - 7s 121ms/step - loss: 1.4722e-05 - val_loss: 5.3536e-04
# Epoch 49/50
# 54/54 [==============================] - 8s 148ms/step - loss: 1.4333e-05 - val_loss: 5.1870e-04
# Epoch 50/50
# 54/54 [==============================] - 7s 124ms/step - loss: 1.4826e-05 - val_loss: 4.9613e-04

# %%
training_time = time.time() - start_time
print("Training Time:", training_time, "seconds")
# Out:
# Training Time: 8.204169273376465 seconds

# %%
# Evaluate model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print('Train Loss:', train_loss)
print('Test Loss:', test_loss)
# Out:
# Train Loss: 0.06463094800710678
# Test Loss: 0.606391966342926

# %%
# Measure prediction time
start_time = time.time()

# %%
# Predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
prediction_time = time.time() - start_time
print("Prediction Time:", prediction_time, "seconds")
# Out:
# Prediction Time: 43.0593204498291 seconds

# %%
# Inverse scaling to get original stock prices
train_predictions = scaler.inverse_transform(train_predictions)
#y_train = scaler.inverse_transform([y_train])
# Reshape y_train if necessary
y_train = np.reshape(y_train, (-1, 1))  # Assuming y_train is a 1D array

# Apply inverse transformation
y_train = scaler.inverse_transform(y_train)
test_predictions = scaler.inverse_transform(test_predictions)


# Reshape y_test if necessary
y_test = np.reshape(y_test, (-1, 1))  # Assuming y_test is a 1D array

# Apply inverse transformation
y_test = scaler.inverse_transform(y_test)

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
#plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
#plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
#plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
#plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %% [markdown]
# <!-- This code demonstrates a simple example of how to build an LSTM-based RNN model for time series prediction using the Google stock prices dataset. Here's a brief overview of the steps:
#
# Load and visualize the dataset.
#
# Normalize the data to the range [0, 1].
#
# Split the data into train and test sets.
#
# Create sequences of data with specified time steps.
#
# Build an LSTM model with two LSTM layers and a Dense output layer.
#
# Compile the model with mean squared error loss and Adam optimizer.
#
# Train the model on the train data.
#
# Evaluate the model on both train and test data.
#
# Inverse scale the predictions to get the original stock prices.
#
# Plot the actual vs predicted stock prices for both train and test data. -->
